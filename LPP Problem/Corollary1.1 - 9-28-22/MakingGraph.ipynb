# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
alphaVals = [0.55, 0.6, 0.65, 0.67, 0.7, 0.8]
ms = [200,400,800]
TV = [[0.229968042128458, 0.262945322237529, 0.3055076279505], [0.199784078916179, 0.198887646227039, 0.22530064897851], [0.174329999329123, 0.166531441326157, 0.152521671937092], [0.133838681856378, 0.160640781645589, 0.143956010085568], [0.128844420694009, 0.103157872665635, 0.113633617392103], [0.0749206261307826, 0.104919079226277, 0.114518857381874]]
clr = ['black', 'y', 'g', 'b', 'r', 'm', 'c']

plt.figure(figsize = (8, 8))
for i in range(len(alphaVals)):
  print("alpha == " + str(alphaVals[i]) + ", " + str(clr[i]))
  plt.plot(ms, TV[i], color = clr[i])
plt.xlabel("Value of m")
plt.ylabel("Total Variation Distance")
plt.title("Total Variation Distance vs m for various alpha values")
plt.show()
# Out:
# alpha == 0.55, black
# alpha == 0.6, y
# alpha == 0.65, g
# alpha == 0.67, b
# alpha == 0.7, r
# alpha == 0.8, m
